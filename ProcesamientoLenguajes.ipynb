# %% [markdown]
# <a href="https://colab.research.google.com/github/hfranc827/Datos/blob/main/ProcesamientoLenguajes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install textblob

# %%
# !python -m textblob.download_corpora
# Out:
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# [nltk_data] Downloading package conll2000 to /root/nltk_data...
# [nltk_data]   Unzipping corpora/conll2000.zip.
# [nltk_data] Downloading package movie_reviews to /root/nltk_data...
# [nltk_data]   Unzipping corpora/movie_reviews.zip.
# Finished.

# %% [markdown]
# ## TextBlob

# %%
# TextBlob es la clase fundamental para NLP con el modulo textblob
from textblob import TextBlob
texto = "Y cuando desperto. Todo a su alrededor era luminoso"
blob = TextBlob(texto)
blob
# Out:
# TextBlob("Y cuando desperto. Todo a su alrededor era luminoso")

# %%
blob.sentences
# Out:
# [Sentence("Y cuando desperto."), Sentence("Todo a su alrededor era luminoso")]

# %%
blob.words
# Out:
# WordList(['Y', 'cuando', 'desperto', 'Todo', 'a', 'su', 'alrededor', 'era', 'luminoso'])

# %%
texto = "I have good discipline to study. In the future I will be a great engineer"
blob = TextBlob(texto)
blob
# Out:
# TextBlob("I have good discipline to study. In the future I will be a great engineer")

# %%
blob.sentences
# Out:
# [Sentence("I have good discipline to study."),
#  Sentence("In the future I will be a great engineer")]

# %%
blob.words
# Out:
# WordList(['I', 'have', 'good', 'discipline', 'to', 'study', 'In', 'the', 'future', 'I', 'will', 'be', 'a', 'great', 'engineer'])

# %%
blob.tags
# Out:
# [('I', 'PRP'),
#  ('have', 'VBP'),
#  ('good', 'JJ'),
#  ('discipline', 'NN'),
#  ('to', 'TO'),
#  ('study', 'VB'),
#  ('In', 'IN'),
#  ('the', 'DT'),
#  ('future', 'NN'),
#  ('I', 'PRP'),
#  ('will', 'MD'),
#  ('be', 'VB'),
#  ('a', 'DT'),
#  ('great', 'JJ'),
#  ('engineer', 'NN')]

# %%
from nltk.corpus import stopwords
stops = stopwords.words("english")
print(stops)
# Out:
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", 'her', 'here', 'hers', 'herself', "he's", 'him', 'himself', 'his', 'how', 'i', "i'd", 'if', "i'll", "i'm", 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', "i've", 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 's
# ...

# %%
from textblob import TextBlob
blob = TextBlob("I have a beatiful day")
TextBlob("I have a beatiful day")
# Out:
# TextBlob("I have a beatiful day")

# %%
[word for word in blob.words if word not in stops]
# Out:
# ['I', 'beatiful', 'day']

# %% [markdown]
# ## Visualizando frecuencias de palabras

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f0cde36e-703c-4d08-b88f-8a71253addc9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f0cde36e-703c-4d08-b88f-8a71253addc9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Leer el contenido del archivo
with open("dracula.txt", "r") as file:
    contenido = file.read()
    print(contenido)
# Out:
# The Project Gutenberg EBook of Dracula, by Bram Stoker
#
# This eBook is for the use of anyone anywhere at no cost and with
# almost no restrictions whatsoever.  You may copy it, give it away or
# re-use it under the terms of the Project Gutenberg License included
# with this eBook or online at www.gutenberg.net
#
#
# Title: Dracula
#
# Author: Bram Stoker
#
# Release Date: May 9, 2008 [EBook #345]
#
# Language: English
#
# Character set encoding: ASCII
#
# *** START OF THIS PROJECT GUTENBERG EBOOK DRACULA ***
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# DRACULA
#
# by
#
# Bram Stoker
#
#
# 1897 edition
#
#
#
#
# TABLE OF CONTENTS
#
#
# CHAPTER
#
#   1  Jonathan Harker's Journal
#   2  Jonathan Harker's Journal
#   3  Jonathan Harker's Journal
#   4  Jonathan Harker's Journal
#   5  Letter From Miss Mina Murray To Miss Lucy Westenra
#   6  Mina Murray's Journal
#   7  Cutting From "The Dailygraph", 8 August
#   8  Mina Murray's Journal
#   9  Letter, Mina Harker To Lucy Westenra
# ...

# %%
from pathlib import Path
from textblob import TextBlob
text = open("dracula.txt",encoding="utf8")
libro_drac = TextBlob(text.read())

# %%
from nltk.corpus import stopwords
stops = stopwords.words("english")

# %%
items = libro_drac.word_counts.items()

# %%
items = [item for item in items if item[0] not in stops]

# %%
from operator import itemgetter
items_ordenados = sorted(items, key=itemgetter(1), reverse=True)

# %%
primeros15 = items_ordenados[:16]

# %%
import pandas as pd
datos = pd.DataFrame(primeros15, columns=["palabra", "frecuencia"])
datos
# Out:
#     palabra  frecuencia
# 0      said         570
# 1     could         505
# 2       one         492
# 3        us         463
# 4      must         449
# 5     would         447
# 6       may         431
# 7     shall         424
# 8      know         397
# 9       see         395
# 10     time         384
# 11     come         337
# 12      van         321
# 13  helsing         321
# 14     came         306
# 15     lucy         302

# %%
ejes = datos.plot.bar(x="palabra", y="frecuencia", legend=False)

# %%
# !pip install wordcloud

# %%
from pathlib import Path
from textblob import TextBlob
from wordcloud import WordCloud , STOPWORDS

# %%
texto = open("dracula.txt",encoding="utf8")
stopwords = set(STOPWORDS)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-85aa377e-1372-4366-9b02-92d5db2b9e04" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-85aa377e-1372-4366-9b02-92d5db2b9e04">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import imageio
mascara = imageio.imread("mask_oval.png")
# Out:
# /tmp/ipython-input-3801099826.py:2: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   mascara = imageio.imread("mask_oval.png")

# %%
drac_nubpal = WordCloud(colormap = "prism" , background_color = "white", max_words = 1000, mask = mascara, stopwords = stopwords)

# %%
drac_nubpal.generate(texto)

# %%
import imageio
import matplotlib.pyplot as plt

# Leer la imagen
mascara = imageio.imread("mask_oval.png")

# Mostrar la imagen para verificar que se cargó correctamente
plt.imshow(mascara)
plt.axis("off")  # Desactivar los ejes
plt.show()
# Out:
# /tmp/ipython-input-3599286441.py:5: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   mascara = imageio.imread("mask_oval.png")

# %%
from wordcloud import WordCloud
from nltk.corpus import stopwords

# Texto para la nube de palabras
#texto = "Python es increíble. Python es fácil. Python es poderoso."

# Descargar stopwords si aún no se han descargado
import nltk
nltk.download('stopwords')
stopwords_list = stopwords.words("english")

# Crear la nube de palabras con la imagen de máscara
drac_nubpal = WordCloud(
    colormap="prism",
    background_color="white",
    max_words=1000,
    mask=mascara,
    stopwords=stopwords_list
)

# Generar la nube de palabras
drac_nubpal.generate(texto)

# Mostrar la nube de palabras
plt.imshow(drac_nubpal, interpolation="bilinear")
plt.axis("off")
plt.show()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import imageio
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from nltk.corpus import stopwords
import nltk

# Descargar stopwords si aún no lo has hecho
nltk.download('stopwords')
stopwords_list = stopwords.words("english")

# Cargar la imagen de la máscara
mascara = imageio.imread("mask_oval.png")  # Asegúrate de que la imagen esté correctamente cargada

# Leer el archivo de texto dracula.txt
with open("dracula.txt", "r", encoding="utf-8") as file:
    texto = file.read()

# Crear la nube de palabras con la imagen de máscara
drac_nubpal = WordCloud(
    colormap="prism",
    background_color="white",
    max_words=1000,
    mask=mascara,
    stopwords=stopwords_list
)

# Generar la nube de palabras
drac_nubpal.generate(texto)

# Mostrar la nube de palabras
plt.imshow(drac_nubpal, interpolation="bilinear")
plt.axis("off")
plt.show()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# /tmp/ipython-input-228305910.py:12: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   mascara = imageio.imread("mask_oval.png")  # Asegúrate de que la imagen esté correctamente cargada

# %%
# Leer el archivo de texto dracula.txt
with open("dracula.txt", "r", encoding="utf-8") as file:
    texto = file.read()

# Mostrar las primeras 500 caracteres para verificar
print(texto[:500])  # Solo imprime los primeros 500 caracteres para confirmar que se leyó correctamente
# Out:
# The Project Gutenberg EBook of Dracula, by Bram Stoker
#
# This eBook is for the use of anyone anywhere at no cost and with
# almost no restrictions whatsoever.  You may copy it, give it away or
# re-use it under the terms of the Project Gutenberg License included
# with this eBook or online at www.gutenberg.net
#
#
# Title: Dracula
#
# Author: Bram Stoker
#
# Release Date: May 9, 2008 [EBook #345]
#
# Language: English
#
# Character set encoding: ASCII
#
# *** START OF THIS PROJECT GUTENBERG EBOOK DRACULA ***

# %%
import imageio

# Leer la imagen de la máscara
mascara = imageio.imread("mask_oval.png")

# Mostrar la imagen para verificar que se cargó correctamente
import matplotlib.pyplot as plt
plt.imshow(mascara)
plt.axis("off")  # Desactivar los ejes
plt.show()
# Out:
# /tmp/ipython-input-676551584.py:4: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   mascara = imageio.imread("mask_oval.png")

# %%
from wordcloud import WordCloud
from nltk.corpus import stopwords
import nltk

# Descargar stopwords si aún no se ha hecho
nltk.download('stopwords')
stopwords_list = stopwords.words("english")

# Crear la nube de palabras con la imagen de máscara
drac_nubpal = WordCloud(
    colormap="prism",
    background_color="white",
    max_words=1000,
    mask=mascara,  # Usando la imagen como máscara
    stopwords=stopwords_list
)

# Generar la nube de palabras usando el texto del archivo
drac_nubpal.generate(texto)

# Mostrar la nube de palabras
plt.imshow(drac_nubpal, interpolation="bilinear")
plt.axis("off")
plt.show()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
